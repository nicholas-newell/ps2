# %%
import pandas as pd

df = pd.read_csv('/blue/zoo6927/share/Jupyter_Content/data/auto_mpg.csv')

# %%
df
# Out:
#       mpg  cyl   disp   hp  weight  accel  year  origin  \
# 0    18.0    8  307.0  130    3504   12.0    70       1
# 1    15.0    8  350.0  165    3693   11.5    70       1
# 2    18.0    8  318.0  150    3436   11.0    70       1
# 3    16.0    8  304.0  150    3433   12.0    70       1
# 4    17.0    8  302.0  140    3449   10.5    70       1
# ..    ...  ...    ...  ...     ...    ...   ...     ...
# 387  27.0    4  140.0   86    2790   15.6    82       1
# 388  44.0    4   97.0   52    2130   24.6    82       2
# 389  32.0    4  135.0   84    2295   11.6    82       1
# 390  28.0    4  120.0   79    2625   18.6    82       1
# 391  31.0    4  119.0   82    2720   19.4    82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
# mpg vs. weight
x = df[['weight']]
y = df[['mpg']]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x,y)

# %%
print(model.intercept_, model.coef_)
# Out:
# [46.21652455] [[-0.00764734]]

# %%
model.score(x,y)
# Out:
# 0.6926304331206254

# %%
df['weight_sq']= df.weight**2
x2= df[['weight', 'weight_sq']]

# %%
model = LinearRegression().fit(x2,y)
print(model.intercept_, model.coef_)
# Out:
# [62.25547397] [[-1.84956106e-02  1.69656507e-06]]

# %%
model.score(x2,y)
# Out:
# 0.7151475557845139

# %%
import numpy as np
import pandas as pd
import plotnine as pn
xvals = np.linspace(x2.weight.min(), x2.weight.max(), len(df))
x_predict = pd.DataFrame({
    'weight': xvals,
    'weight_sq': xvals**2
})

# %%
y_predict = model.predict(x_predict)

# %%
pn.ggplot(df, pn.aes(x='weight', y='mpg')) + pn.geom_point() + pn.geom_line(mapping=pn.aes(x=xvals, y=y_predict), color='red', size=1.0)
# Out:
# <ggplot: (2997731716021)>

# %%
# mpg vs disp
x = df[['disp']]
y = df[['mpg']]

from sklearn.linear_model import LinearRegression


df['disp_sq']= df.disp**2
x2= df[['disp', 'disp_sq']]

model = LinearRegression().fit(x2,y)

import numpy as np
import pandas as pd
import plotnine as pn

xvals = np.linspace(x2.disp.min(), x2.disp.max(), len(df))
x_predict = pd.DataFrame({
    'disp': xvals,
    'disp_sq': xvals**2
})

y_predict = model.predict(x_predict)

pn.ggplot(df, pn.aes(x='disp', y='mpg')) + pn.geom_point() + pn.geom_line(mapping=pn.aes(x=xvals, y=y_predict), color='blue', size=1.0)
# Out:
# <ggplot: (2997553344296)>

# %%
model.score(x2,y)
# Out:
# 0.688808733323848

# %%
# mpg vs cyl
x = df[['cyl']]
y = df[['mpg']]

from sklearn.linear_model import LinearRegression


df['cyl_sq']= df.cyl**2
x2= df[['cyl', 'cyl_sq']]

model = LinearRegression().fit(x2,y)

import numpy as np
import pandas as pd
import plotnine as pn

xvals = np.linspace(x2.cyl.min(), x2.cyl.max(), len(df))
x_predict = pd.DataFrame({
    'cyl': xvals,
    'cyl_sq': xvals**2
})

y_predict = model.predict(x_predict)

pn.ggplot(df, pn.aes(x='cyl', y='mpg')) + pn.geom_point() + pn.geom_line(mapping=pn.aes(x=xvals, y=y_predict), color='green', size=1.0)
# Out:
# <ggplot: (2997569059103)>

# %%
model.score(x2,y)
# Out:
# 0.6074524159772413

# %%
# cyl vs disp 
x = df[['disp']]
y = df[['cyl']]

from sklearn.linear_model import LinearRegression


df['disp_sq']= df.disp**2
x2= df[['disp', 'disp_sq']]

model = LinearRegression().fit(x2,y)

import numpy as np
import pandas as pd
import plotnine as pn

xvals = np.linspace(x2.disp.min(), x2.disp.max(), len(df))
x_predict = pd.DataFrame({
    'disp': xvals,
    'disp_sq': xvals**2
})

y_predict = model.predict(x_predict)

pn.ggplot(df, pn.aes(x='disp', y='cyl')) + pn.geom_point() + pn.geom_line(mapping=pn.aes(x=xvals, y=y_predict), color='orange', size=1.0)
# Out:
# <ggplot: (2974388208454)>

# %%
model.score(x2,y)
# Out:
# 0.9165606659538106
